# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel75-svg/1f-PA-grupo-A/blob/main/Aula_dia_10_03_1F_grupo_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calcular a área do retângulo

# %%
 # Entrada
 comprimento = float(input("Digite o comprimento do retângulo:"))
 altura = float(input("Digite a altura do retângulo;"))

 # Processamento

 area = comprimento * altura

 # Saída

 print (f"O total da área do retângulo é:{area}")
# Out:
# Digite o comprimento do retângulo:3
# Digite a altura do retângulo;3
# O total da área do retângulo é:9.0

# %% [markdown]
# Fazer um cadastro de usuário:
#
# Objetivo trabalhar com sting (str)
#
# Entrada de dados: Nome e idade
# Processamento: armazenar os dados
# Saída: mostrar uma mensagem de olá e a idade do usuário

# %%
 # entrada
 nome = str(input("Digite seu nome: "))
 idade = int(input("Digite sua idade: "))

 # Saída

 print (f"Olá {nome}, seja bem vindo!")
 print (f"você tem {idade} anos.")
# Out:
# Digite seu nome: Gabriel
# Digite sua idade: 15
# Olá Gabriel, seja bem vindo!
# você tem 15 anos.

# %% [markdown]
# Fazer um programa que calcula o dobro de um número
#
# Entrada: um número
#
# Processamento: Calcular o dobro
#
# Saída: mostrar o resultado

# %%
 # Entrada

 Numero = int (input("Digite um número: "))

  # Processamento

Dobro = Numero + Numero

  # Saída

print (f"o dobro do numero {Numero} é igual a {Dobro}")
# Out:
# Digite um número: 2
# o dobro do numero 2 é igual a 4

# %% [markdown]
# Escrever um programa que calcula a media das notas do aluno.
#
# Entrada: nome, idade e as 04 notas so bimestre
#
# Processamento: calcular a media
#
# Saída: mostrar o nome do aluno e a média obtida

# %%
 # Entrada

 nome = str(input("Digite seu nome: "))
 idade = int(input("Digite sua idade: "))
 nota1 = float(input("Digite sua nota1: "))
 nota2 = float(input("Digite sua nota2: "))
 nota3 = float(input("Digite sua nota3: "))
 nota4 = float(input("Digite sua nota4: "))

 # Processamento

 media = (nota1 + nota2 + nota3 + nota4) / 4

 # Saída

print (f"olá {nome}, seja bem vindo!")
print (f"você tem {idade} anos")
print (f"sua média é igual {media}")
# Out:
# Digite seu nome: gabriel
# Digite sua idade: 15
# Digite sua nota1: 6
# Digite sua nota2: 7
# Digite sua nota3: 8
# Digite sua nota4: 10
# olá gabriel, seja bem vindo!
# você tem 15 anos
# sua média é igual 7.75
