# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel75-svg/1f-PA-grupo-A/blob/main/Aula_26_05_PA_grupoA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Calculadora com as 4 operações

# Menu

while True:
    print("\n--- MENU ---")
    print("Opção 1 - Somar")
    print("Opção 2 - Subtrair")
    print("Opção 3 - Multiplicar")
    print("Opção 4 - Divisão")
    print("Opção 5 - Sair")
    print("------------")

    try:
        opcao = int(input("Digite uma opção: "))

        if opcao == 5:
            print("Saindo da calculadora. Até mais!")
            break # Sai do loop e encerra o programa
        elif 1 <= opcao <= 4:
            num1 = int(input("Digite o primeiro número: "))
            num2 = int(input("Digite o segundo número: "))

            if opcao == 1:
                resultado = num1 + num2
                print(f"A soma é: {resultado}")
            elif opcao == 2:
                resultado = num1 - num2
                print(f"A subtração é: {resultado}")
            elif opcao == 3:
                resultado = num1 * num2
                print(f"A multiplicação é: {resultado}")
            elif opcao == 4:
                if num2 != 0:
                    resultado = num1 / num2
                    print(f"A divisão é: {resultado}")
                else:
                    print("Erro: Divisão por zero não é permitida.")
        else:
            print("Opção inválida. Por favor, digite um número entre 1 e 5.")

    except ValueError:
        print("Entrada inválida. Por favor, digite um número para a opção e para os números da operação.")
# Out:
# --- MENU ---
# Opção 1 - Somar
# Opção 2 - Subtrair
# Opção 3 - Multiplicar
# Opção 4 - Divisão
# Opção 5 - Sair
# ------------
# Digite uma opção: 1
# Digite o primeiro número: 10
# Digite o segundo número: 9
# A soma é: 19
#
# --- MENU ---
# Opção 1 - Somar
# Opção 2 - Subtrair
# Opção 3 - Multiplicar
# Opção 4 - Divisão
# Opção 5 - Sair
# ------------
# Digite uma opção: 5
# Saindo da calculadora. Até mais!

# %%
# Jogo Inteligente

# 1 - par / impar
# 2 - positivo
# 3 - maior de 02 números
# 4 - sair

print ("--- MENU ---")
print("1 - par / impar")
print("2 - positivo")
print("3 - maior de 02 números")
print("4 - sair")
print("")

while True:
  opcao = int(input("Digite uma opção: "))

  if opcao == 1:

    numero = int(input("Digite um número: "))

    if numero % 2 == 0:
      print("O número é par.")
    else:
      print("O número é ímpar!")

  elif opcao == 2:

    if numero > 0:
      print("O número é positivo.")
    else:
      print("O número é negativo!")
# Out:
# --- MENU ---
# 1 - par / impar
# 2 - positivo
# 3 - maior de 02 números
# 4 - sair
#
# Digite uma opção: 1
# Digite um número: 4
# O número é par.

# %%
# Escrever um programa que verifica a senha, o usúario terá 3 tentativas caso erre as 03 imprimir mensagem de "acesso negado e tente novamente mais tarde!" e encerrar o programa.

senha = "123456"

tentativas = 0
# Out:
# Digite a senha: 24352
# Senha incorreta.
# Digite a senha: 23123
# Senha incorreta.
# Digite a senha: 1231
# Senha incorreta.
# Digite a senha: 31232
# Senha incorreta.
# Digite a senha:
# Senha incorreta.
# Digite a senha:
# Senha incorreta.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8770/4198368621.py in <cell line: 0>()
#       5
#       6 while tentativas < 3:
# ----> 7     tentativa = input("Digite a senha: ")
#       8     if tentativa == senha:
#       9         print("Acesso permitido!")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
