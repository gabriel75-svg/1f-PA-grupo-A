# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel75-svg/1f-PA-grupo-A/blob/main/aula_02_06_grupoA_1F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Projeto caixa eletronico

# Você foi contratado para desenvolver um sistema simples de caixa eletronico.

# O sistema deverá funcionar através de um menu interativo utilizando "while"

# O programa deve iniciar com um saldo inicial de R$1000,00 e permitir que o usúario escolha diferentes operações até decidir sair do sistema.

# Ver saldo
# Depositar
# Sacar dinheiro
# Sair

# Regras:

# Quando depositar somar ao  saldo anterior;
# Quando Sacar subtrair do saldo anterior
# Mostrar o saldo para o usúario

saldo = 1000.00 # Initialize saldo

runnig = True
while True:
    print("------------MENU------------") # Fixed syntax error
    print("1. Ver saldo")
    print("2. Depositar")
    print("3. Sacar")
    print("4. Sair")
    print("----------------------------")

    try:
        opcao = int(input("Escolha uma opção: "))
    except ValueError:
        print("Opção inválida. Por favor, digite um número.")
        continue

    if opcao == 1:
        print(f"Seu saldo é de R${saldo:.2f}") # Display dynamic saldo
    elif opcao == 2:
        try:
            valor = float(input("Digite o valor a ser depositado: "))
            if valor > 0:
                saldo += valor
                print(f"Depósito realizado com sucesso! Seu novo saldo é de R${saldo:.2f}")
            else:
                print("O valor do depósito deve ser positivo.")
        except ValueError:
            print("Valor inválido. Por favor, digite um número.")
    elif opcao == 3: # Sacar money
        try:
            valor = float(input("Digite o valor a ser sacado: "))
            if valor <= 0:
                print("O valor do saque deve ser positivo.")
            elif valor > saldo:
                print("Saldo insuficiente.")
            else:
                saldo -= valor
                print(f"Saque realizado com sucesso! Seu novo saldo é de R${saldo:.2f}")
        except ValueError:
            print("Valor inválido. Por favor, digite um número.")
    elif opcao == 4:
        print("Saindo do sistema. Obrigado por usar nosso caixa eletrônico!")
        running = False # Exit the loop
    else:
        print("Opção inválida. Por favor, escolha uma opção entre 1 e 4.")
    print()
# Out:
# ------------MENU------------
# 1. Ver saldo
# 2. Depositar
# 3. Sacar
# 4. Sair
# ----------------------------
# Escolha uma opção: 4
# Saindo do sistema. Obrigado por usar nosso caixa eletrônico!
#
# ------------MENU------------
# 1. Ver saldo
# 2. Depositar
# 3. Sacar
# 4. Sair
# ----------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11194/540173661.py in <cell line: 0>()
#      30
#      31     try:
# ---> 32         opcao = int(input("Escolha uma opção: "))
#      33     except ValueError:
#      34         print("Opção inválida. Por favor, digite um número.")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
# ...
