# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel75-svg/1f-PA-grupo-A/blob/main/HelloWord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("wello word")
# Out:
# wello word
